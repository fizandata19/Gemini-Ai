# %% [markdown]
# <a href="https://colab.research.google.com/github/fizandata19/Gemini-Ai/blob/main/Few_Shot_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Correct Imports
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI  # Corrected Import
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.schema import Document
import os

# Set your Google API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyDAgT8gD2srcmTnDytluOjt9XVNCp8t3-w"  # Replace with your actual API key

# Step 1: Create Few-shot Examples
examples = [
    {"question": "What is a CPU?", "answer": "A CPU (Central Processing Unit) is the main processing unit of a computer that executes instructions."},
    {"question": "What is RAM?", "answer": "RAM (Random Access Memory) is a type of computer memory that stores data temporarily for quick access."},
    {"question": "What is an OS?", "answer": "An OS (Operating System) is system software that manages hardware and software resources."},
    {"question": "What is cloud computing?", "answer": "Cloud computing is the delivery of computing services over the internet, such as storage and processing power."},
    {"question": "What is AI?", "answer": "AI (Artificial Intelligence) is the simulation of human intelligence in machines."},
    {"question": "What is Machine Learning?", "answer": "Machine Learning is a subset of AI that enables systems to learn from data and improve over time."},
    {"question": "What is Deep Learning?", "answer": "Deep Learning is a subset of Machine Learning that uses neural networks to model complex patterns."},
    {"question": "What is Python?", "answer": "Python is a high-level programming language known for its simplicity and readability."},
    {"question": "What is an API?", "answer": "An API (Application Programming Interface) allows different software applications to communicate with each other."},
    {"question": "What is a database?", "answer": "A database is an organized collection of data that can be accessed and managed electronically."},
    {"question": "What is SQL?", "answer": "SQL (Structured Query Language) is used to manage and manipulate relational databases."},
    {"question": "What is NoSQL?", "answer": "NoSQL is a type of database that stores data in a non-tabular format, suitable for big data applications."},
    {"question": "What is a Neural Network?", "answer": "A Neural Network is a computational model inspired by the human brain that is used in AI applications."},
    {"question": "What is a Compiler?", "answer": "A Compiler is a program that translates source code into executable machine code."},
    {"question": "What is an Interpreter?", "answer": "An Interpreter directly executes code without converting it into machine code first."},
    {"question": "What is a Framework?", "answer": "A Framework is a pre-built structure that simplifies software development."},
    {"question": "What is a Library?", "answer": "A Library is a collection of reusable code that developers can use in their programs."},
    {"question": "What is Open Source?", "answer": "Open Source refers to software whose source code is freely available for modification and distribution."},
    {"question": "What is Git?", "answer": "Git is a version control system used to track changes in code and collaborate with teams."},
    {"question": "What is GitHub?", "answer": "GitHub is an online platform for hosting and managing Git repositories."},
    {"question": "What is JSON?", "answer": "JSON (JavaScript Object Notation) is a lightweight data format used for data exchange."},
    {"question": "What is XML?", "answer": "XML (eXtensible Markup Language) is a markup language used to store and transport data."},
    {"question": "What is REST API?", "answer": "A REST API (Representational State Transfer API) is a web service that follows REST principles."},
    {"question": "What is a Web Server?", "answer": "A Web Server is a software or hardware system that serves web pages to users."},
    {"question": "What is a Frontend?", "answer": "Frontend refers to the user-facing part of a website or application."},
    {"question": "What is a Backend?", "answer": "Backend refers to the server-side logic and database management of an application."},
    {"question": "What is Full Stack Development?", "answer": "Full Stack Development refers to the development of both frontend and backend components."},
    {"question": "What is Cybersecurity?", "answer": "Cybersecurity is the practice of protecting systems, networks, and data from cyber threats."},
    {"question": "What is Encryption?", "answer": "Encryption is the process of converting data into a secure format to prevent unauthorized access."},
    {"question": "What is a Firewall?", "answer": "A Firewall is a security system that monitors and controls incoming and outgoing network traffic."},
    {"question": "What is Phishing?", "answer": "Phishing is a cyber attack that involves tricking individuals into revealing sensitive information."},
    {"question": "What is Big Data?", "answer": "Big Data refers to large volumes of data that require specialized tools for processing and analysis."},
    {"question": "What is IoT?", "answer": "IoT (Internet of Things) refers to interconnected devices that communicate over the internet."},
    {"question": "What is Blockchain?", "answer": "Blockchain is a decentralized ledger technology used to record transactions securely."},
    {"question": "What is Cryptocurrency?", "answer": "Cryptocurrency is a digital currency that uses cryptography for security."},
    {"question": "What is Bitcoin?", "answer": "Bitcoin is a decentralized digital currency that operates on blockchain technology."},
    {"question": "What is Ethereum?", "answer": "Ethereum is a blockchain-based platform that enables smart contracts and decentralized applications."},
    {"question": "What is an NFT?", "answer": "An NFT (Non-Fungible Token) is a unique digital asset that represents ownership of a specific item."},
    {"question": "What is Cloud Storage?", "answer": "Cloud Storage is a service that allows users to store data online instead of on local devices."},
    {"question": "What is Virtual Reality?", "answer": "Virtual Reality (VR) is a technology that creates an immersive digital environment."},
    {"question": "What is Augmented Reality?", "answer": "Augmented Reality (AR) overlays digital content onto the real world using a device."},
    {"question": "What is 5G?", "answer": "5G is the fifth generation of mobile network technology that offers faster speeds and lower latency."},
    {"question": "What is Edge Computing?", "answer": "Edge Computing processes data closer to the source rather than relying on centralized data centers."},
    {"question": "What is Quantum Computing?", "answer": "Quantum Computing is a computing technology that leverages quantum mechanics to perform complex calculations."}
]


# Convert the examples into LangChain Documents
docs = [Document(page_content=f"Q: {ex['question']}\nA: {ex['answer']}") for ex in examples]

# Step 2: Generate Embeddings and Store in FAISS
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")  # Google's Gemini Embedding Model
vectorstore = FAISS.from_documents(docs, embeddings)
retriever = vectorstore.as_retriever(search_kwargs={"k": 2})  # Retrieve top 2 relevant examples

# Step 3: Set Up the RAG Model
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", temperature=1.0)  # Corrected parameter

qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

# Step 4: Query the RAG System
query = "What is an Ai?"
response = qa_chain.run(query)

print("Answer:", response)
# Out:
# Answer: AI (Artificial Intelligence) is the simulation of human intelligence in machines.
